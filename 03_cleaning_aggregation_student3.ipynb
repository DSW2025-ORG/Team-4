# %% [markdown]
# # STUDENT 3 - CURĂȚARE ȘI AGREGARE DATE

# %% [markdown]
# ## Curatarea datelor - EIA

# %%
import pandas as pd

# %%
eia = pd.read_csv("eia_africa_countries_raw.csv")
eia.head ()
# Out:
#    period  productId  productName  activityId activityName countryRegionId  \
# 0    2023          2  Electricity           2  Consumption             AGO
# 1    2023          2  Electricity           2  Consumption             BDI
# 2    2023          2  Electricity           2  Consumption             BEN
# 3    2023          2  Electricity           2  Consumption             BFA
# 4    2023          2  Electricity           2  Consumption             BWA
#
#   countryRegionName countryRegionTypeId countryRegionTypeName  dataFlagId  \
# 0            Angola                   c               Country         NaN
# 1           Burundi                   c               Country         NaN
# 2             Benin                   c               Country         NaN
# 3      Burkina Faso                   c               Country         NaN
# 4          Botswana                   c               Country         NaN
#
#   dataFlagDescription               unitName         value  unit
# ...

# %%
eia = pd.read_csv("eia_africa_countries_raw.csv")
eia
# Out:
#        period  productId  productName  activityId activityName  \
# 0        2023          2  Electricity           2  Consumption
# 1        2023          2  Electricity           2  Consumption
# 2        2023          2  Electricity           2  Consumption
# 3        2023          2  Electricity           2  Consumption
# 4        2023          2  Electricity           2  Consumption
# ...       ...        ...          ...         ...          ...
# 68265    2001       4702   Population          33   Population
# 68266    2001       4702   Population          33   Population
# 68267    2001       4702   Population          33   Population
# 68268    2001       4702   Population          33   Population
# 68269    2001       4702   Population          33   Population
#
#       countryRegionId countryRegionName countryRegionTypeId  \
# 0                 AGO            Angola                   c
# 1                 BDI           Burundi                   c
# ...

# %% [markdown]
# ### Verificarea coloanelor disponibile și tipul acestora

# %%
print("Coloanele disponibile:\n", eia.columns,"\nPrimele 2 randuri:")
eia.head(2)
# Out:
# Coloanele disponibile:
#  Index(['period', 'productId', 'productName', 'activityId', 'activityName',
#        'countryRegionId', 'countryRegionName', 'countryRegionTypeId',
#        'countryRegionTypeName', 'dataFlagId', 'dataFlagDescription',
#        'unitName', 'value', 'unit'],
#       dtype='object')
# Primele 2 randuri:
#    period  productId  productName  activityId activityName countryRegionId  \
# 0    2023          2  Electricity           2  Consumption             AGO
# 1    2023          2  Electricity           2  Consumption             BDI
#
#   countryRegionName countryRegionTypeId countryRegionTypeName  dataFlagId  \
# 0            Angola                   c               Country         NaN
# 1           Burundi                   c               Country         NaN
#
#   dataFlagDescription               unitName         value  unit
# 0                 NaN  billion kilowatthours  16.213833931  BKWH
# 1                 NaN  billion kilowatthours    .444018308  BKWH

# %%
print("Dimensiune dataframe:", eia.shape)
print("\nTipuri de date:")
print(eia.dtypes)
# Out:
# Dimensiune dataframe: (68270, 14)
#
# Tipuri de date:
# period                     int64
# productId                  int64
# productName               object
# activityId                 int64
# activityName              object
# countryRegionId           object
# countryRegionName         object
# countryRegionTypeId       object
# countryRegionTypeName     object
# dataFlagId               float64
# dataFlagDescription       object
# unitName                  object
# value                     object
# unit                      object
# dtype: object

# %%
eia['countryRegionTypeName'].value_counts()
# Out:
# countryRegionTypeName
# Country    68270
# Name: count, dtype: int64

# %% [markdown]
# ### Verificarea unităților și clarificarea lor

# %%
eia['unit'].value_counts().head(20)
# Out:
# unit
# BKWH         17354
# MTOE         12386
# QBTU         12386
# TJ           12386
# MK            7452
# THP           1296
# BDOLPPP       1284
# MMTCD         1242
# TBTUUSDPP     1242
# MBTUPP        1242
# Name: count, dtype: int64

# %% [markdown]
# Unitati multiple
# - QBTU       (Quadrillion BTU)
# - MTOE       (Million tonnes oil equivalent)
# - TJ         (Terajoules)
# - BKWH       (Billion kWh)
# - MT         (Thousand metric tons)
# - TST        (Thousand short tons)
# - MMTCD      (Million metric tons CO2)
# - BDOLPPP    (Billion dollars PPP)

# %% [markdown]
# ### Verificarea datelor lipsa pentru fiecare coloana

# %%
print("\nProcent lipsuri pe coloană (%):")
print((eia.isna().mean() * 100).round(2))
# Out:
# Procent lipsuri pe coloană (%):
# period                    0.00
# productId                 0.00
# productName               0.00
# activityId                0.00
# activityName              0.00
# countryRegionId           0.00
# countryRegionName         0.00
# countryRegionTypeId       0.00
# countryRegionTypeName     0.00
# dataFlagId               82.09
# dataFlagDescription      82.09
# unitName                  0.00
# value                     0.00
# unit                      0.00
# dtype: float64

# %%
print("\nTop 10 produse:")
print(eia['productName'].value_counts())
# Out:
# Top 10 produse:
# productName
# Electricity               19736
# Primary energy             7452
# Renewables                 6210
# Hydroelectricity           6210
# Solar                      6210
# Wind                       6210
# Nuclear                    6210
# Energy intensity           2484
# Population                 1296
# Gross domestic product     1284
# Natural gas                1242
# Oil                        1242
# Coal                       1242
# CO2 emissions              1242
# Name: count, dtype: int64

# %%
print("\nTop 10 activități:")
print(eia['activityName'].value_counts().head(10))
# Out:
# Top 10 activități:
# activityName
# Generation             29808
# Capacity                7452
# Consumption             4968
# Net imports             4964
# Imports                 4964
# Exports                 4840
# Production              3726
# Population              2538
# GDP                     2526
# Distribution losses     1242
# Name: count, dtype: int64

# %% [markdown]
# ### Identificarea anilor disponibili în dataset

# %%
print(eia.productId.unique())
# Out:
# [   2   30   31   32   29   37  116   33   27   44 4008   47 4701 4702]

# %%
print("\nAni în dataset:")
print(eia['period'].unique())
# Out:
# Ani în dataset:
# [2023 2022 2021 2020 2019 2018 2017 2016 2015 2014 2013 2012 2011 2010
#  2009 2008 2007 2006 2005 2004 2003 2002 2001 2024]

# %% [markdown]
# ### Identificarea tuturor indicatorilor disponibili

# %%
eia[["productId", "productName", "activityName", "activityId"]].drop_duplicates().sort_values("productName")
# Out:
#        productId             productName         activityName  activityId
# 61964       4008           CO2 emissions            Emissions           8
# 19736         30                    Coal           Generation          12
# 0              2             Electricity          Consumption           2
# 54             2             Electricity              Imports           3
# 266            2             Electricity              Exports           4
# 354            2             Electricity             Capacity           7
# 408            2             Electricity  Distribution losses           9
# 462            2             Electricity           Generation          12
# 516            2             Electricity          Net imports          23
# 63260         47        Energy intensity                  GDP          34
# 63206         47        Energy intensity           Population          33
# 65690       4701  Gross domestic product                  GDP          34
# ...

# %% [markdown]
# ### Redenumirea coloanelor și eliminarea coloanelor nefolositoare

# %%
eia_std = eia.copy()

# %%
eia_std = eia_std.rename(columns={
    'period': 'year',
    'countryRegionId': 'country_iso3',
    'countryRegionName': 'country_name',
    'unitName': 'unit_name'
})

# %%
eia_std.columns
# Out:
# Index(['year', 'productId', 'productName', 'activityId', 'activityName',
#        'country_iso3', 'country_name', 'countryRegionTypeId',
#        'countryRegionTypeName', 'dataFlagId', 'dataFlagDescription',
#        'unit_name', 'value', 'unit'],
#       dtype='object')

# %%
for col in ['productName', 'activityName', 'unit_name']:
    eia_std[col] = (
        eia_std[col]
            .astype(str)
            .str.strip()
            .str.lower()
            .str.replace(r'\s+', '_', regex=True)
    )

# %% [markdown]
# ### Construirea unui nou indicator nume pentru indicatori din produs si activitate

# %%
eia_std['indicator_name'] = (
    eia_std['productName'] + '_' + eia_std['activityName']
)
eia_std.indicator_name.unique()
# Out:
# array(['electricity_consumption', 'electricity_imports',
#        'electricity_exports', 'electricity_capacity',
#        'electricity_distribution_losses', 'electricity_generation',
#        'electricity_net_imports', 'coal_generation',
#        'natural_gas_generation', 'oil_generation', 'renewables_capacity',
#        'renewables_generation', 'wind_capacity', 'wind_generation',
#        'solar_capacity', 'solar_generation', 'hydroelectricity_capacity',
#        'hydroelectricity_generation', 'nuclear_capacity',
#        'nuclear_generation', 'primary_energy_production',
#        'primary_energy_consumption', 'co2_emissions_emissions',
#        'energy_intensity_population', 'energy_intensity_gdp',
#        'gross_domestic_product_gdp', 'population_population'],
#       dtype=object)

# %%
eia_std.loc[
    eia_std['productName'] == eia_std['activityName'],
    'indicator_name'
] = eia_std['productName']

eia_std.indicator_name.unique()
# Out:
# array(['electricity_consumption', 'electricity_imports',
#        'electricity_exports', 'electricity_capacity',
#        'electricity_distribution_losses', 'electricity_generation',
#        'electricity_net_imports', 'coal_generation',
#        'natural_gas_generation', 'oil_generation', 'renewables_capacity',
#        'renewables_generation', 'wind_capacity', 'wind_generation',
#        'solar_capacity', 'solar_generation', 'hydroelectricity_capacity',
#        'hydroelectricity_generation', 'nuclear_capacity',
#        'nuclear_generation', 'primary_energy_production',
#        'primary_energy_consumption', 'co2_emissions_emissions',
#        'energy_intensity_population', 'energy_intensity_gdp',
#        'gross_domestic_product_gdp', 'population'], dtype=object)

# %%
len(eia_std.indicator_name.unique())
# Out:
# 27

# %% [markdown]
# #### Și acum un indicator code

# %%
eia_std['indicator_code'] = (
    eia_std['productName'].str[:4].str.upper() + "_" +
    eia_std['activityName'].str[:3].str.upper()
)
eia_std['indicator_code'].unique()
# Out:
# array(['ELEC_CON', 'ELEC_IMP', 'ELEC_EXP', 'ELEC_CAP', 'ELEC_DIS',
#        'ELEC_GEN', 'ELEC_NET', 'COAL_GEN', 'NATU_GEN', 'OIL_GEN',
#        'RENE_CAP', 'RENE_GEN', 'WIND_CAP', 'WIND_GEN', 'SOLA_CAP',
#        'SOLA_GEN', 'HYDR_CAP', 'HYDR_GEN', 'NUCL_CAP', 'NUCL_GEN',
#        'PRIM_PRO', 'PRIM_CON', 'CO2__EMI', 'ENER_POP', 'ENER_GDP',
#        'GROS_GDP', 'POPU_POP'], dtype=object)

# %% [markdown]
# #### Pentru un indicator label

# %%
eia_std['indicator_label'] = (
    eia_std['productName'].str.replace('_', ' ').str.title()
    + " – " +
    eia_std['activityName'].str.replace('_', ' ').str.title()
)
eia_std.indicator_label.unique()
# Out:
# array(['Electricity – Consumption', 'Electricity – Imports',
#        'Electricity – Exports', 'Electricity – Capacity',
#        'Electricity – Distribution Losses', 'Electricity – Generation',
#        'Electricity – Net Imports', 'Coal – Generation',
#        'Natural Gas – Generation', 'Oil – Generation',
#        'Renewables – Capacity', 'Renewables – Generation',
#        'Wind – Capacity', 'Wind – Generation', 'Solar – Capacity',
#        'Solar – Generation', 'Hydroelectricity – Capacity',
#        'Hydroelectricity – Generation', 'Nuclear – Capacity',
#        'Nuclear – Generation', 'Primary Energy – Production',
#        'Primary Energy – Consumption', 'Co2 Emissions – Emissions',
#        'Energy Intensity – Population', 'Energy Intensity – Gdp',
#        'Gross Domestic Product – Gdp', 'Population – Population'],
#       dtype=object)

# %%
eia_std['countryRegionTypeName'] = eia_std['countryRegionTypeName'].str.lower()

# %%
eia_std['countryRegionTypeName'].unique()
# Out:
# array(['country'], dtype=object)

# %% [markdown]
# ### Gestionarea valorilor lipsa

# %%
print("Procent lipsuri pe coloană (%):")
print((eia_std.isna().mean() * 100).round(2))
# Out:
# Procent lipsuri pe coloană (%):
# year                      0.00
# productId                 0.00
# productName               0.00
# activityId                0.00
# activityName              0.00
# country_iso3              0.00
# country_name              0.00
# countryRegionTypeId       0.00
# countryRegionTypeName     0.00
# dataFlagId               82.09
# dataFlagDescription      82.09
# unit_name                 0.00
# value                     0.00
# unit                      0.00
# indicator_name            0.00
# indicator_code            0.00
# indicator_label           0.00
# dtype: float64

# %%
print("Numar de valori lipsa pentru coloana value")
print(eia_std.value.isna().sum())
# Out:
# Numar de valori lipsa pentru coloana value
# 0

# %%
missing_by_year = (
    eia_std.groupby('year')['value']
           .apply(lambda x: x.isna().mean())
)
print("\nLipsuri pe an (%):")
print((missing_by_year * 100).round(2).head(20))
# Out:
# Lipsuri pe an (%):
# year
# 2001    0.0
# 2002    0.0
# 2003    0.0
# 2004    0.0
# 2005    0.0
# 2006    0.0
# 2007    0.0
# 2008    0.0
# 2009    0.0
# 2010    0.0
# 2011    0.0
# 2012    0.0
# 2013    0.0
# 2014    0.0
# 2015    0.0
# 2016    0.0
# 2017    0.0
# 2018    0.0
# 2019    0.0
# 2020    0.0
# Name: value, dtype: float64

# %%
eia_country = eia_std[eia_std["countryRegionTypeName"] == "country"].copy()
eia_region = eia_std[eia_std["countryRegionTypeName"] == "region"].copy()

# %% [markdown]
# ### Stergeera coloanelor nefolositoare

# %%
cols_to_drop = [
    'productId',
    'activityId',
    'countryRegionTypeId',
    'countryRegionTypeName',
    'dataFlagId',
    'dataFlagDescription',
    'productName',        
    'activityName'       
]
 
eia_clean = eia_country.drop(columns=cols_to_drop)

# %%
eia_clean = eia_clean.dropna(how='all')
 
eia_clean = eia_clean.drop_duplicates(keep='first')

# %%
eia_clean= eia_clean[[
    'country_iso3',
    'country_name',
    'year',
    'indicator_code',
    'indicator_name',
    'indicator_label',
    'unit',
    'unit_name',
    'value'
]].copy()

# %% [markdown]
# ### Eliminarea anilor 2001 și 2024

# %%
An = 2001
eia_clean = eia_clean[eia_clean['year'] != An].copy()

# %%
An = 2024
eia_clean = eia_clean[eia_clean['year'] != An].copy()

# %%
eia_clean['year'].value_counts()
# Out:
# year
# 2022    2970
# 2021    2970
# 2019    2970
# 2020    2970
# 2018    2970
# 2017    2970
# 2013    2970
# 2016    2970
# 2015    2970
# 2014    2970
# 2009    2969
# 2012    2969
# 2011    2969
# 2010    2969
# 2005    2969
# 2008    2969
# 2007    2969
# 2006    2969
# 2003    2969
# 2004    2969
# 2002    2969
# 2023    2834
# Name: count, dtype: int64

# %%
eia_clean.to_csv("eia_clean.csv", index = False)

# %%
eia_clean.head(2)
# Out:
#   country_iso3 country_name  year indicator_code           indicator_name  \
# 0          AGO       Angola  2023       ELEC_CON  electricity_consumption
# 1          BDI      Burundi  2023       ELEC_CON  electricity_consumption
#
#              indicator_label  unit              unit_name         value
# 0  Electricity – Consumption  BKWH  billion_kilowatthours  16.213833931
# 1  Electricity – Consumption  BKWH  billion_kilowatthours    .444018308

# %% [markdown]
# ## Curatarea datelor WDI

# %% [markdown]
# ### Familiarizarea cu datele

# %%
import pandas as pd
import numpy as np

# %%
wdi = pd.read_csv("wdi_africa_countries_raw.csv")
print(wdi.shape)
print(wdi.columns)
wdi.head(3)
# Out:
# (10368, 6)
# Index(['Country_Name', 'Country_Code', 'Year', 'Indicator_Name',
#        'Indicator_Code', 'Value'],
#       dtype='object')
#        Country_Name Country_Code  Year      Indicator_Name  Indicator_Code  \
# 0          Djibouti          DJI  2000  access_electricity  EG.ELC.ACCS.ZS
# 1  Egypt, Arab Rep.          EGY  2000  access_electricity  EG.ELC.ACCS.ZS
# 2          Zimbabwe          ZWE  2000  access_electricity  EG.ELC.ACCS.ZS
#
#    Value
# 0   56.0
# 1   97.7
# 2   33.7

# %%
wdi.shape
# Out:
# (10368, 6)

# %%
wdi.columns
# Out:
# Index(['Country_Name', 'Country_Code', 'Year', 'Indicator_Name',
#        'Indicator_Code', 'Value'],
#       dtype='object')

# %%
wdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10368 entries, 0 to 10367
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country_Name    10368 non-null  object
#  1   Country_Code    10368 non-null  object
#  2   Year            10368 non-null  int64
#  3   Indicator_Name  10368 non-null  object
#  4   Indicator_Code  10368 non-null  object
#  5   Value           8954 non-null   float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 486.1+ KB

# %%
wdi.dtypes
# Out:
# Country_Name       object
# Country_Code       object
# Year                int64
# Indicator_Name     object
# Indicator_Code     object
# Value             float64
# dtype: object

# %%
wdi['Value'].apply(type).value_counts(). head()
# Out:
# Value
# <class 'float'>    10368
# Name: count, dtype: int64

# %%
wdi.describe()
# Out:
#               Year         Value
# count  10368.00000   8954.000000
# mean    2011.50000    341.971792
# std        6.92252   1350.807018
# min     2000.00000     -2.590877
# 25%     2005.75000     -0.806856
# 50%     2011.50000      0.161913
# 75%     2017.25000     49.900000
# max     2023.00000  19481.646105

# %%
wdi.describe(include='object')
# Out:
#        Country_Name Country_Code      Indicator_Name  Indicator_Code
# count         10368        10368               10368           10368
# unique           54           54                   8               8
# top        Djibouti          DJI  access_electricity  EG.ELC.ACCS.ZS
# freq            192          192                1296            1296

# %%
wdi.isna().mean().sort_values(ascending=False)
# Out:
# Value             0.136381
# Country_Name      0.000000
# Country_Code      0.000000
# Year              0.000000
# Indicator_Name    0.000000
# Indicator_Code    0.000000
# dtype: float64

# %%
wdi.columns
# Out:
# Index(['Country_Name', 'Country_Code', 'Year', 'Indicator_Name',
#        'Indicator_Code', 'Value'],
#       dtype='object')

# %%
pd.to_datetime(wdi['Year'], errors='coerce').isna().sum()
# Out:
# np.int64(0)

# %%
wdi['Indicator_Name'].value_counts()
# Out:
# Indicator_Name
# access_electricity    1296
# urban_population      1296
# gdp_per_capita        1296
# gov_effectiveness     1296
# regulatory_quality    1296
# rule_of_law           1296
# control_corruption    1296
# gini_coefficient      1296
# Name: count, dtype: int64

# %%
print(wdi.columns)
wdi.head(3)
# Out:
# Index(['Country_Name', 'Country_Code', 'Year', 'Indicator_Name',
#        'Indicator_Code', 'Value'],
#       dtype='object')
#        Country_Name Country_Code  Year      Indicator_Name  Indicator_Code  \
# 0          Djibouti          DJI  2000  access_electricity  EG.ELC.ACCS.ZS
# 1  Egypt, Arab Rep.          EGY  2000  access_electricity  EG.ELC.ACCS.ZS
# 2          Zimbabwe          ZWE  2000  access_electricity  EG.ELC.ACCS.ZS
#
#    Value
# 0   56.0
# 1   97.7
# 2   33.7

# %%
wdi['Value'] = pd.to_numeric(wdi['Value'], errors='coerce')

# %%
wdi['Year'] = wdi['Year'].astype(int)

# %%
wdi['Indicator_Name'].str.strip().str.lower().str.replace(' ', '_').str.replace(r'[^0-9a-zA-Z_]', '', regex=True)
# Out:
# 0        access_electricity
# 1        access_electricity
# 2        access_electricity
# 3        access_electricity
# 4        access_electricity
#                 ...
# 10363      gini_coefficient
# 10364      gini_coefficient
# 10365      gini_coefficient
# 10366      gini_coefficient
# 10367      gini_coefficient
# Name: Indicator_Name, Length: 10368, dtype: object

# %%
wdi.head(3)
# Out:
#        Country_Name Country_Code  Year      Indicator_Name  Indicator_Code  \
# 0          Djibouti          DJI  2000  access_electricity  EG.ELC.ACCS.ZS
# 1  Egypt, Arab Rep.          EGY  2000  access_electricity  EG.ELC.ACCS.ZS
# 2          Zimbabwe          ZWE  2000  access_electricity  EG.ELC.ACCS.ZS
#
#    Value
# 0   56.0
# 1   97.7
# 2   33.7

# %%
wdi.isna().sum()
# Out:
# Country_Name         0
# Country_Code         0
# Year                 0
# Indicator_Name       0
# Indicator_Code       0
# Value             1414
# dtype: int64

# %%
wdi.isna().mean().sort_values(ascending=False)
# Out:
# Value             0.136381
# Country_Name      0.000000
# Country_Code      0.000000
# Year              0.000000
# Indicator_Name    0.000000
# Indicator_Code    0.000000
# dtype: float64

# %%
(wdi['Value'].isna()
        .groupby(wdi['Indicator_Code'])
        .mean()
        .sort_values())
# Out:
# Indicator_Code
# SP.URB.TOTL.IN.ZS    0.000000
# EG.ELC.ACCS.ZS       0.012346
# NY.GDP.PCAP.KD       0.031636
# CC.EST               0.048611
# RQ.EST               0.049383
# RL.EST               0.049383
# GE.EST               0.050154
# SI.POV.GINI          0.849537
# Name: Value, dtype: float64

# %%
wdi.groupby('Country_Code')['Value'].apply(lambda x: x.isna().mean()).sort_values().head()
# Out:
# Country_Code
# EGY    0.104167
# RWA    0.114583
# NGA    0.114583
# ZMB    0.114583
# UGA    0.114583
# Name: Value, dtype: float64

# %%
wdi.groupby('Year')['Value'].apply(lambda x: x.isna().mean()).sort_values(ascending=False).head(10)
# Out:
# Year
# 2001    0.625000
# 2000    0.127315
# 2003    0.127315
# 2004    0.127315
# 2006    0.127315
# 2023    0.127315
# 2007    0.125000
# 2002    0.122685
# 2020    0.120370
# 2008    0.120370
# Name: Value, dtype: float64

# %%
wdi.columns
# Out:
# Index(['Country_Name', 'Country_Code', 'Year', 'Indicator_Name',
#        'Indicator_Code', 'Value'],
#       dtype='object')

# %%
missing_by_year = wdi.groupby('Year')['Value'].apply(lambda x: x.isna().mean())  

years_over_40 = missing_by_year[missing_by_year > 0.40]  
years_over_40
# Out:
# Year
# 2001    0.625
# Name: Value, dtype: float64

# %%
years_keep = list(range(2000, 2024)) 
years_keep = missing_by_year[missing_by_year < 0.50].index
wdi = wdi[wdi['Year'].isin(years_keep)].copy()

# %%
wdi.groupby('Year')['Value'].apply(lambda x: x.isna().mean())
# Out:
# Year
# 2000    0.127315
# 2002    0.122685
# 2003    0.127315
# 2004    0.127315
# 2005    0.118056
# 2006    0.127315
# 2007    0.125000
# 2008    0.120370
# 2009    0.118056
# 2010    0.106481
# 2011    0.104167
# 2012    0.108796
# 2013    0.115741
# 2014    0.106481
# 2015    0.097222
# 2016    0.113426
# 2017    0.113426
# 2018    0.094907
# 2019    0.115741
# 2020    0.120370
# 2021    0.094907
# 2022    0.115741
# 2023    0.127315
# Name: Value, dtype: float64

# %%
wdi['Value'].isna().mean()
# Out:
# np.float64(0.11513687600644122)

# %%
wdi.duplicated(subset=['Country_Code','Year','Indicator_Code']).sum()
# Out:
# np.int64(0)

# %%
wdi_wide = (
    wdi
        .pivot(
            index=['Country_Code','Year'],
            columns='Indicator_Name',
            values='Value'
        )
        .reset_index()
)
wdi_wide.head(2)
# Out:
# Indicator_Name Country_Code  Year  access_electricity  control_corruption  \
# 0                       AGO  2000                24.2           -1.197514
# 1                       AGO  2002                26.3           -1.155493
#
# Indicator_Name  gdp_per_capita  gini_coefficient  gov_effectiveness  \
# 0                  1932.988479              51.9          -1.075034
# 1                  2139.872597               NaN          -1.132157
#
# Indicator_Name  regulatory_quality  rule_of_law  urban_population
# 0                        -1.507048    -1.601502            50.087
# 1                        -1.294135    -1.633344            52.461

# %%
# ============================================================
# VALIDARE FINALĂ WDI (totul într-o singură celulă)
# ============================================================

# 1. Duplicate country-year
print("Duplicate country-year:", 
      wdi_wide.duplicated(subset=['Country_Code','Year']).sum())

# 2. Lipsuri pe coloane
print("\nProcent lipsuri pe coloană (%):")
print((wdi_wide.isna().mean() * 100).round(2))

# 3. Valori imposibile la procente (>100)
pct_cols = [c for c in wdi_wide.columns 
            if 'percent' in c or '_zs' in c or '_pct' in c]
print("\nValori >100% (indicatori procentuali):")
for col in pct_cols:
    print(col, (wdi_wide[col] > 100).sum())


# 5. Acoperire temporală (câte rânduri per an)
print("\nNumăr observații pe an:")
print(wdi_wide.groupby('Year').size())

# 6. Număr țări
print("\nNumăr țări unice:", wdi_wide['Country_Code'].nunique())

# 7. Dimensiune finală a tabelului
print("\nDimensiune finală tabel:", wdi_wide.shape)
# Out:
# Duplicate country-year: 0
#
# Procent lipsuri pe coloană (%):
# Indicator_Name
# Country_Code           0.00
# Year                   0.00
# access_electricity     1.05
# control_corruption     0.72
# gdp_per_capita         3.14
# gini_coefficient      84.70
# gov_effectiveness      0.89
# regulatory_quality     0.81
# rule_of_law            0.81
# urban_population       0.00
# dtype: float64
#
# Valori >100% (indicatori procentuali):
#
# Număr observații pe an:
# Year
# 2000    54
# 2002    54
# 2003    54
# 2004    54
# 2005    54
# 2006    54
# 2007    54
# 2008    54
# 2009    54
# 2010    54
# 2011    54
# 2012    54
# 2013    54
# 2014    54
# 2015    54
# 2016    54
# 2017    54
# 2018    54
# 2019    54
# 2020    54
# 2021    54
# 2022    54
# 2023    54
# dtype: int64
#
# Număr țări unice: 54
#
# Dimensiune finală tabel: (1242, 10)

# %%
wdi_wide
# Out:
# Indicator_Name Country_Code  Year  access_electricity  control_corruption  \
# 0                       AGO  2000                24.2           -1.197514
# 1                       AGO  2002                26.3           -1.155493
# 2                       AGO  2003                27.4           -1.335463
# 3                       AGO  2004                28.4           -1.377569
# 4                       AGO  2005                29.4           -1.323182
# ...                     ...   ...                 ...                 ...
# 1237                    ZWE  2019                46.7           -1.290334
# 1238                    ZWE  2020                52.7           -1.308788
# 1239                    ZWE  2021                49.0           -1.277147
# 1240                    ZWE  2022                50.1           -1.259969
# 1241                    ZWE  2023                62.0           -1.261216
#
# Indicator_Name  gdp_per_capita  gini_coefficient  gov_effectiveness  \
# ...

# %%
wdi
# Out:
#            Country_Name Country_Code  Year      Indicator_Name  \
# 0              Djibouti          DJI  2000  access_electricity
# 1      Egypt, Arab Rep.          EGY  2000  access_electricity
# 2              Zimbabwe          ZWE  2000  access_electricity
# 3                Zambia          ZMB  2000  access_electricity
# 4              Tanzania          TZA  2000  access_electricity
# ...                 ...          ...   ...                 ...
# 10363      Burkina Faso          BFA  2023    gini_coefficient
# 10364          Botswana          BWA  2023    gini_coefficient
# 10365             Benin          BEN  2023    gini_coefficient
# 10366            Angola          AGO  2023    gini_coefficient
# 10367           Algeria          DZA  2023    gini_coefficient
#
#        Indicator_Code  Value
# 0      EG.ELC.ACCS.ZS   56.0
# 1      EG.ELC.ACCS.ZS   97.7
# 2      EG.ELC.ACCS.ZS   33.7
# 3      EG.ELC.ACCS.ZS   16.7
# 4      EG.ELC.ACCS.ZS    8.7
# ...

# %%
# ============================================================
# VALIDARE FINALĂ WDI (totul într-o singură celulă)
# ============================================================

# 1. Duplicate country-year
print("Duplicate country-year:", 
      wdi_wide.duplicated(subset=['Country_Code','Year']).sum())

# 2. Lipsuri pe coloane
print("\nProcent lipsuri pe coloană (%):")
print((wdi_wide.isna().mean() * 100).round(2))

# 3. Valori imposibile la procente (>100)
pct_cols = [c for c in wdi_wide.columns 
            if 'percent' in c or '_zs' in c or '_pct' in c]
print("\nValori >100% (indicatori procentuali):")
for col in pct_cols:
    print(col, (wdi_wide[col] > 100).sum())


# 5. Acoperire temporală (câte rânduri per an)
print("\nNumăr observații pe an:")
print(wdi_wide.groupby('Year').size())

# 6. Număr țări
print("\nNumăr țări unice:", wdi_wide['Country_Code'].nunique())

# 7. Dimensiune finală a tabelului
print("\nDimensiune finală tabel:", wdi_wide.shape)
# Out:
# Duplicate country-year: 0
#
# Procent lipsuri pe coloană (%):
# Indicator_Name
# Country_Code           0.00
# Year                   0.00
# access_electricity     1.05
# control_corruption     0.72
# gdp_per_capita         3.14
# gini_coefficient      84.70
# gov_effectiveness      0.89
# regulatory_quality     0.81
# rule_of_law            0.81
# urban_population       0.00
# dtype: float64
#
# Valori >100% (indicatori procentuali):
#
# Număr observații pe an:
# Year
# 2000    54
# 2002    54
# 2003    54
# 2004    54
# 2005    54
# 2006    54
# 2007    54
# 2008    54
# 2009    54
# 2010    54
# 2011    54
# 2012    54
# 2013    54
# 2014    54
# 2015    54
# 2016    54
# 2017    54
# 2018    54
# 2019    54
# 2020    54
# 2021    54
# 2022    54
# 2023    54
# dtype: int64
#
# Număr țări unice: 54
#
# Dimensiune finală tabel: (1242, 10)

# %%
wdi_wide.columns
# Out:
# Index(['Country_Code', 'Year', 'access_electricity', 'control_corruption',
#        'gdp_per_capita', 'gini_coefficient', 'gov_effectiveness',
#        'regulatory_quality', 'rule_of_law', 'urban_population'],
#       dtype='object', name='Indicator_Name')

# %%
 wdi['Indicator_Name'].value_counts()
# Out:
# Indicator_Name
# access_electricity    1242
# urban_population      1242
# gdp_per_capita        1242
# gov_effectiveness     1242
# regulatory_quality    1242
# rule_of_law           1242
# control_corruption    1242
# gini_coefficient      1242
# Name: count, dtype: int64

# %%
wdi_wide
# Out:
# Indicator_Name Country_Code  Year  access_electricity  control_corruption  \
# 0                       AGO  2000                24.2           -1.197514
# 1                       AGO  2002                26.3           -1.155493
# 2                       AGO  2003                27.4           -1.335463
# 3                       AGO  2004                28.4           -1.377569
# 4                       AGO  2005                29.4           -1.323182
# ...                     ...   ...                 ...                 ...
# 1237                    ZWE  2019                46.7           -1.290334
# 1238                    ZWE  2020                52.7           -1.308788
# 1239                    ZWE  2021                49.0           -1.277147
# 1240                    ZWE  2022                50.1           -1.259969
# 1241                    ZWE  2023                62.0           -1.261216
#
# Indicator_Name  gdp_per_capita  gini_coefficient  gov_effectiveness  \
# ...

# %%
wdi
# Out:
#            Country_Name Country_Code  Year      Indicator_Name  \
# 0              Djibouti          DJI  2000  access_electricity
# 1      Egypt, Arab Rep.          EGY  2000  access_electricity
# 2              Zimbabwe          ZWE  2000  access_electricity
# 3                Zambia          ZMB  2000  access_electricity
# 4              Tanzania          TZA  2000  access_electricity
# ...                 ...          ...   ...                 ...
# 10363      Burkina Faso          BFA  2023    gini_coefficient
# 10364          Botswana          BWA  2023    gini_coefficient
# 10365             Benin          BEN  2023    gini_coefficient
# 10366            Angola          AGO  2023    gini_coefficient
# 10367           Algeria          DZA  2023    gini_coefficient
#
#        Indicator_Code  Value
# 0      EG.ELC.ACCS.ZS   56.0
# 1      EG.ELC.ACCS.ZS   97.7
# 2      EG.ELC.ACCS.ZS   33.7
# 3      EG.ELC.ACCS.ZS   16.7
# 4      EG.ELC.ACCS.ZS    8.7
# ...

# %%
wdi['Year'].value_counts()
# Out:
# Year
# 2000    432
# 2002    432
# 2003    432
# 2004    432
# 2005    432
# 2006    432
# 2007    432
# 2008    432
# 2009    432
# 2010    432
# 2011    432
# 2012    432
# 2013    432
# 2014    432
# 2015    432
# 2016    432
# 2017    432
# 2018    432
# 2019    432
# 2020    432
# 2021    432
# 2022    432
# 2023    432
# Name: count, dtype: int64

# %%
indicator = "gini_coefficient"
wdi = wdi[wdi['Indicator_Name'] != indicator].copy()

# %%
wdi.to_csv("wdi_clean.csv")
wdi_wide.to_csv("wdi_wide.csv")

# %% [markdown]
# # CONCATENAREA TABELELOR

# %%
import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os

# %%
NEON_URL="postgresql://dsw_writer:3dsadasf%25%40%23%40@ep-royal-scene-agnlimgp-pooler.c-2.eu-central-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require"

# %%
# create engine using sqlalchemy
engine = create_engine(os.getenv("NEON_URL"))

# %%
print(engine)
# Out:
# Engine(postgresql://dsw_writer:***@ep-royal-scene-agnlimgp-pooler.c-2.eu-central-1.aws.neon.tech/neondb?channel_binding=require&sslmode=require)

# %%
wdi_clean = pd.read_csv("wdi_clean.csv")
eia_clean = pd.read_csv("eia_clean.csv")

# %%
wdi_clean.to_sql(
    "Team4_wdi_cleann",
    engine,
    if_exists="replace",
    index=False
)
# Out:
# 694

# %%
eia_clean.to_sql(
    "Team4_eia_clean",
    engine,
    if_exists="replace",
    index=False
)
# Out:
# 193

# %%
print(eia_clean.columns)
print(wdi_clean.columns)
# Out:
# Index(['country_iso3', 'country_name', 'year', 'indicator_code',
#        'indicator_name', 'indicator_label', 'unit', 'unit_name', 'value'],
#       dtype='object')
# Index(['Unnamed: 0', 'Country_Name', 'Country_Code', 'Year', 'Indicator_Name',
#        'Indicator_Code', 'Value'],
#       dtype='object')

# %%
cols_to_drop = [
    'indicator_label',      
    'unit',
    'unit_name'
]
 
eia_clean = eia_clean.drop(columns=cols_to_drop)

# %%
print(eia_clean.columns)
print(wdi_clean.columns)
# Out:
# Index(['country_iso3', 'country_name', 'year', 'indicator_code',
#        'indicator_name', 'value'],
#       dtype='object')
# Index(['Unnamed: 0', 'Country_Name', 'Country_Code', 'Year', 'Indicator_Name',
#        'Indicator_Code', 'Value'],
#       dtype='object')

# %%
ordine_noua = [
    'Country_Code', 
    'Country_Name', 
    'Year',
    'Indicator_Code',
    'Indicator_Name', 
    'Value'
]

wdi_clean = wdi_clean[ordine_noua]

# %%
print(eia_clean.columns)
print(wdi_clean.columns)
# Out:
# Index(['country_iso3', 'country_name', 'year', 'indicator_code',
#        'indicator_name', 'value'],
#       dtype='object')
# Index(['Country_Code', 'Country_Name', 'Year', 'Indicator_Code',
#        'Indicator_Name', 'Value'],
#       dtype='object')

# %%
wdi_clean
# Out:
#      Country_Code      Country_Name  Year  Indicator_Code      Indicator_Name  \
# 0             DJI          Djibouti  2000  EG.ELC.ACCS.ZS  access_electricity
# 1             EGY  Egypt, Arab Rep.  2000  EG.ELC.ACCS.ZS  access_electricity
# 2             ZWE          Zimbabwe  2000  EG.ELC.ACCS.ZS  access_electricity
# 3             ZMB            Zambia  2000  EG.ELC.ACCS.ZS  access_electricity
# 4             TZA          Tanzania  2000  EG.ELC.ACCS.ZS  access_electricity
# ...           ...               ...   ...             ...                 ...
# 8689          BFA      Burkina Faso  2023          CC.EST  control_corruption
# 8690          BWA          Botswana  2023          CC.EST  control_corruption
# 8691          BEN             Benin  2023          CC.EST  control_corruption
# 8692          AGO            Angola  2023          CC.EST  control_corruption
# 8693          DZA           Algeria  2023          CC.EST  control_corruption
#
#           Value
# ...

# %%
missing = wdi_clean[wdi_clean["Country_Name"].isna()]
missing.Country_Code.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
print(eia_clean.columns)
print(wdi_clean.columns)
# Out:
# Index(['country_iso3', 'country_name', 'year', 'indicator_code',
#        'indicator_name', 'value'],
#       dtype='object')
# Index(['Country_Code', 'Country_Name', 'Year', 'Indicator_Code',
#        'Indicator_Name', 'Value'],
#       dtype='object')

# %%
 wdi_clean['Indicator_Name'].value_counts()
# Out:
# Indicator_Name
# access_electricity    1242
# urban_population      1242
# gdp_per_capita        1242
# gov_effectiveness     1242
# regulatory_quality    1242
# rule_of_law           1242
# control_corruption    1242
# Name: count, dtype: int64

# %%
wdi_clean = wdi_clean.rename(columns={
    'Year': 'year',
})

# %%
(wdi_clean['Value'].isna()
        .groupby(wdi['Indicator_Code'])
        .mean()
        .sort_values())
# Out:
# Indicator_Code
# SP.URB.TOTL.IN.ZS    0.006823
# NY.GDP.PCAP.KD       0.008772
# CC.EST               0.009747
# GE.EST               0.010721
# RL.EST               0.010721
# EG.ELC.ACCS.ZS       0.011111
# RQ.EST               0.011696
# Name: Value, dtype: float64

# %%
print(eia_clean.columns)
print(wdi_clean.columns)
# Out:
# Index(['country_iso3', 'country_name', 'year', 'indicator_code',
#        'indicator_name', 'value'],
#       dtype='object')
# Index(['Country_Code', 'Country_Name', 'year', 'Indicator_Code',
#        'Indicator_Name', 'Value'],
#       dtype='object')

# %%
print(eia_clean.columns)
print(wdi_clean.columns)
# Out:
# Index(['country_iso3', 'country_name', 'year', 'indicator_code',
#        'indicator_name', 'value'],
#       dtype='object')
# Index(['Country_Code', 'Country_Name', 'year', 'Indicator_Code',
#        'Indicator_Name', 'Value'],
#       dtype='object')

# %%
wdi_clean = wdi_clean.rename(columns={
    'Country_Code': 'country_iso3',
    'Country_Name': 'country_name',
    'Value': 'value',
    'Indicator_Code': 'indicator_code',
    'Indicator_Name': 'indicator_name',
})

# %%
print(eia_clean.columns)
print(wdi_clean.columns)
# Out:
# Index(['country_iso3', 'country_name', 'year', 'indicator_code',
#        'indicator_name', 'value'],
#       dtype='object')
# Index(['country_iso3', 'country_name', 'year', 'indicator_code',
#        'indicator_name', 'value'],
#       dtype='object')

# %%
# creem wdi final
wdi_final = wdi_clean[[
    "country_iso3",
    "country_name",
    "year",
    "indicator_name",
    "indicator_code",
    "value"
]].copy()
 
# creem eia final
eia_final = eia_clean[[
    "country_iso3",
    "country_name",
    "year",
    "indicator_name",
    "indicator_code",
    "value"
]].copy()
 
eia_final["value"] = pd.to_numeric(eia_final["value"], errors="coerce")

# %%
print(eia_final.columns)
print(wdi_final.columns)
# Out:
# Index(['country_iso3', 'country_name', 'year', 'indicator_name',
#        'indicator_code', 'value'],
#       dtype='object')
# Index(['country_iso3', 'country_name', 'year', 'indicator_name',
#        'indicator_code', 'value'],
#       dtype='object')

# %%
wdi_final
# Out:
#      country_iso3      country_name  year      indicator_name  indicator_code  \
# 0             DJI          Djibouti  2000  access_electricity  EG.ELC.ACCS.ZS
# 1             EGY  Egypt, Arab Rep.  2000  access_electricity  EG.ELC.ACCS.ZS
# 2             ZWE          Zimbabwe  2000  access_electricity  EG.ELC.ACCS.ZS
# 3             ZMB            Zambia  2000  access_electricity  EG.ELC.ACCS.ZS
# 4             TZA          Tanzania  2000  access_electricity  EG.ELC.ACCS.ZS
# ...           ...               ...   ...                 ...             ...
# 8689          BFA      Burkina Faso  2023  control_corruption          CC.EST
# 8690          BWA          Botswana  2023  control_corruption          CC.EST
# 8691          BEN             Benin  2023  control_corruption          CC.EST
# 8692          AGO            Angola  2023  control_corruption          CC.EST
# 8693          DZA           Algeria  2023  control_corruption          CC.EST
#
#           value
# ...

# %%
team4_all_data_long = pd.concat([wdi_final, eia_final], ignore_index = True)

# %%
team4_all_data_long
# Out:
#       country_iso3      country_name  year      indicator_name  \
# 0              DJI          Djibouti  2000  access_electricity
# 1              EGY  Egypt, Arab Rep.  2000  access_electricity
# 2              ZWE          Zimbabwe  2000  access_electricity
# 3              ZMB            Zambia  2000  access_electricity
# 4              TZA          Tanzania  2000  access_electricity
# ...            ...               ...   ...                 ...
# 73882          TZA          Tanzania  2002          population
# 73883          UGA            Uganda  2002          population
# 73884          ZAF      South Africa  2002          population
# 73885          ZMB            Zambia  2002          population
# 73886          ZWE          Zimbabwe  2002          population
#
#        indicator_code     value
# 0      EG.ELC.ACCS.ZS     56.00
# 1      EG.ELC.ACCS.ZS     97.70
# 2      EG.ELC.ACCS.ZS     33.70
# 3      EG.ELC.ACCS.ZS     16.70
# 4      EG.ELC.ACCS.ZS      8.70
# ...

# %%
team4_all_data_long.to_csv("all_data_long.csv", index = False)

# %%
wdi_final.to_csv("wdi_final.csv", index = False)

# %%
eia_final.to_csv("eia_final.csv", index = False)

# %%
import pandas as pd
wdi_africa_countries_raw = pd.read_csv("wdi_africa_countries_raw.csv")

# %%
import pandas as pd

# %%
team4_all_data_long = pd.read_csv("all_data_long.csv")

# %%
import pandas as pd
team4_all_data_long_pivotat = team4_all_data_long.pivot_table(
    index=['country_name', 'year'],  
    columns='indicator_name',        
    values='value'                   
)

print(team4_all_data_long_pivotat.head(2))
# Out:
# indicator_name     access_electricity  co2_emissions_emissions  \
# country_name year
# Algeria      2000                98.6                      NaN
#              2002                98.6                72.178921
#
# indicator_name     coal_generation  control_corruption  electricity_capacity  \
# country_name year
# Algeria      2000              NaN           -0.987298                   NaN
#              2002              0.0           -0.928755                 6.835
#
# indicator_name     electricity_consumption  electricity_distribution_losses  \
# country_name year
# Algeria      2000                      NaN                              NaN
#              2002                   23.279                            4.346
#
# indicator_name     electricity_exports  electricity_generation  \
# country_name year
# Algeria      2000                  NaN                     NaN
#              2002           233.160863                  27.647
#
# ...

# %%
team4_all_data_long_pivotat
# Out:
# indicator_name     access_electricity  co2_emissions_emissions  \
# country_name year
# Algeria      2000                98.6                      NaN
#              2002                98.6                72.178921
#              2003                98.6                72.478917
#              2004                98.6                71.878509
#              2005                98.6                82.857279
# ...                               ...                      ...
# Zimbabwe     2019                46.7                 9.511752
#              2020                52.7                 7.687652
#              2021                49.0                 8.108755
#              2022                50.1                14.380704
#              2023                62.0                12.578125
#
# indicator_name     coal_generation  control_corruption  electricity_capacity  \
# country_name year
# Algeria      2000              NaN           -0.987298                   NaN
# ...

# %%
team4_all_data_long_pivotat = team4_all_data_long_pivotat.reset_index()
team4_all_data_long_pivotat.columns.name = None
team4_all_data_long_pivotat.to_csv('all_data_long_pivotat.csv', index=False)
